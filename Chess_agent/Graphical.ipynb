# %%
# import chessmaster
from chessmaster import Chessmaster

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# get chessmaster instance
chessmaster = Chessmaster()

# %%
# train agent with 2000 iterations (Duration on medium pc ~ 7 min per Iteration)
chessmaster.train_agent(2000)
# Out:
# Loaded model
# Iteration:  0
# Iteration:  5
# Iteration:  10
# Iteration:  15
# Iteration:  20
# Iteration:  25
# Iteration:  30
# Iteration:  35
# Iteration:  40
# Iteration:  45
# Iteration:  50
# Iteration:  55
# Iteration:  60
# Iteration:  65
# Iteration:  70
# Iteration:  75
# Iteration:  80
# Iteration:  85
# Iteration:  90
# Iteration:  95
# Iteration:  100
# Iteration:  105
# Iteration:  110
# Iteration:  115
# Iteration:  120
# Iteration:  125
# Iteration:  130
# Iteration:  135
# Iteration:  140
# Iteration:  145
# Iteration:  150
# Iteration:  155
# Iteration:  160
# Iteration:  165
# Iteration:  170
# Iteration:  175
# Iteration:  180
# Iteration:  185
# Iteration:  190
# Iteration:  195
# Iteration:  200
# Iteration:  205
# Iteration:  210
# Iteration:  215
# Iteration:  220
# Iteration:  225
# Iteration:  230
# Iteration:  235
# Iteration:  240
# Iteration:  245
# Iteration:  250
# Iteration:  255
# Iteration:  260
# Iteration:  265
# Iteration:  270
# ...

# %%
# plot reward trace
chessmaster.plot_reward_trace()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-5675d6816ab4> in <module>
#       1 # plot reward trace
# ----> 2 chessmaster.plot_reward_trace()
#
# ~/Documents/Github/chessmaster/Chess_agent/chessmaster.py in plot_reward_trace(self)
#      68
#      69         reward = pd.DataFrame(self.chess.reward_trace[1:]) # exclude first game (distort graph)
# ---> 70         reward.rolling(window = 500, min_periods = 0).mean().plot(figsize = (16, 9), title = "Average Reward")
#      71         plt.show()
#      72
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...

# %%
# plot (piece) balance trace
chessmaster.plot_balance_trace()

# %%
# make sure chessboard is reseted
chessmaster.chess.reset()
# play against chessmaster
chessmaster.play()
# Out:
# Loaded model
# Starting turn:  AI
# Welcome to your chess game:
#
# --------------------------------------------------
# Actual Board in Turn:  1
# Enter fromsquare:tosquare, e.g. (a2a3)
# Type your move here: b7b5
# --------------------------------------------------
# Actual Board in Turn:  2
# --------------------------------------------------
# Actual Board in Turn:  3
# Enter fromsquare:tosquare, e.g. (a2a3)
# Type your move here: b5b4
# --------------------------------------------------
# Actual Board in Turn:  4
# --------------------------------------------------
# Actual Board in Turn:  5
# Enter fromsquare:tosquare, e.g. (a2a3)
# Type your move here: b4c3
# --------------------------------------------------
# Actual Board in Turn:  6
# --------------------------------------------------
# Actual Board in Turn:  7
# Enter fromsquare:tosquare, e.g. (a2a3)
# Type your move here: c8a6
# --------------------------------------------------
# Actual Board in Turn:  8
# ...
